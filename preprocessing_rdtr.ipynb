# %%
import arcpy
import arcgis
import os
from datetime import datetime
import pandas as pd

# %%
workspace = r'E:\PROJECT\JAKARTASATU'
workspace
# Out:
# 'E:\\PROJECT\\JAKARTASATU'

# %%
os.listdir(os.path.join(workspace, 'RTRW Jakarta'))
# Out:
# ['1.Pola Ruang RTRW',
#  '2.Pola Ruang RDTR',
#  '3.Hasil Union',
#  '4.Ketentuan Khusus',
#  '5.Badan Jalan',
#  'Kodefikasi.xlsx',
#  'Layer Simbolisasi Pola Ruang']

# %%
rdtr = os.path.join(workspace, 'RTRW Jakarta', '2.Pola Ruang RDTR', 'Standar Basis Data Peta RDTR Kabupaten-Kota.gdb', '_31_5RD_AR_PR_RDTRDKIJAKARTA_2021')
sdf_rdtr = pd.DataFrame.spatial.from_featureclass(rdtr)
sdf_rdtr.head(10)
# Out:
#    OBJECTID                   NAMOBJ    NAMZON      KODZON      NAMSZN  \
# 0    895222  Pertahanan dan Keamanan  32130000  32130000.0  32130000.0
# 1    895223              Badan Jalan  32010000  32010000.0  32010000.0
# 2    895224              Badan Jalan  32010000  32010000.0  32010000.0
# 3    895225              Badan Jalan  32010000  32010000.0  32010000.0
# 4    895226              Badan Jalan  32010000  32010000.0  32010000.0
# 5    895227              Badan Jalan  32010000  32010000.0  32010000.0
# 6    895228              Badan Jalan  32010000  32010000.0  32010000.0
# 7    895229              Badan Jalan  32010000  32010000.0  32010000.0
# 8    895230              Badan Jalan  32010000  32010000.0  32010000.0
# 9    895231              Badan Jalan  32010000  32010000.0  32010000.0
#
#      KODSZN      JNSRPR KODEWP KODSWP KODBLK  ...     HANKAM     KKARST  \
# 0  32130000  32000000.0      I      A      1  ...  Tidak Ada  Tidak Ada
# 1  32010000  32000000.0      I      A      1  ...  Tidak Ada  Tidak Ada
# 2  32010000  32000000.0      I      A      1  ...  Tidak Ada  Tidak Ada
# 3  32010000  32000000.0      I      A      1  ...  Tidak Ada  Tidak Ada
# 4  32010000  32000000.0      I      A      1  ...  Tidak Ada  Tidak Ada
# 5  32010000  32000000.0      I      A      1  ...  Tidak Ada  Tidak Ada
# 6  32010000  32000000.0      I      A      1  ...  Tidak Ada  Tidak Ada
# 7  32010000  32000000.0      I      A      1  ...  Tidak Ada  Tidak Ada
# 8  32010000  32000000.0      I      A      1  ...  Tidak Ada  Tidak Ada
# 9  32010000  32000000.0      I      A      1  ...  Tidak Ada  Tidak Ada
#
#       PTBGMB     MGRSAT     RDBUMI TPZ_00             REMARK    LUASHA KODUNK  \
# 0  Tidak Ada  Tidak Ada  Tidak Ada   None  Koramil 04 Gambir  0.052159   HK-1
# 1  Tidak Ada  Tidak Ada  Tidak Ada   None               None  0.034398   BJ-2
# 2  Tidak Ada  Tidak Ada  Tidak Ada   None               None  0.112966   BJ-3
# 3  Tidak Ada  Tidak Ada  Tidak Ada   None               None  0.024990   BJ-4
# 4  Tidak Ada  Tidak Ada  Tidak Ada   None               None  0.141197   BJ-5
# 5  Tidak Ada  Tidak Ada  Tidak Ada   None               None  0.108227   BJ-6
# 6  Tidak Ada  Tidak Ada  Tidak Ada   None               None  0.290645   BJ-7
# 7  Tidak Ada  Tidak Ada  Tidak Ada   None               None  0.149252   BJ-8
# 8  Tidak Ada  Tidak Ada  Tidak Ada   None               None  0.015453   BJ-9
# 9  Tidak Ada  Tidak Ada  Tidak Ada   None               None  0.027772  BJ-10
#
#                                                SHAPE
# 0  {"hasZ": true, "rings": [[[106.80158603410501,...
# 1  {"hasZ": true, "curveRings": [[[106.8055202764...
# 2  {"hasZ": true, "rings": [[[106.80827275092503,...
# 3  {"hasZ": true, "curveRings": [[[106.8071590657...
# 4  {"hasZ": true, "curveRings": [[[106.8080569222...
# 5  {"hasZ": true, "curveRings": [[[106.8029827332...
# 6  {"hasZ": true, "curveRings": [[[106.8063217837...
# 7  {"hasZ": true, "curveRings": [[[106.8104045538...
# 8  {"hasZ": true, "curveRings": [[[106.8074551760...
# 9  {"hasZ": true, "curveRings": [[[106.8064540361...
#
# [10 rows x 34 columns]

# %%
sdf_rdtr.columns
# Out:
# Index(['OBJECTID', 'NAMOBJ', 'NAMZON', 'KODZON', 'NAMSZN', 'KODSZN', 'JNSRPR',
#        'KODEWP', 'KODSWP', 'KODBLK', 'KODSBL', 'WADMPR', 'WADMKK', 'WADMKC',
#        'WADMKD', 'KKOP', 'LP2B', 'KRB', 'TOD', 'TEB', 'PUSLIT', 'CAGBUD',
#        'RESAIR', 'KSMPDN', 'HANKAM', 'KKARST', 'PTBGMB', 'MGRSAT', 'RDBUMI',
#        'TPZ_00', 'REMARK', 'LUASHA', 'KODUNK', 'SHAPE'],
#       dtype='object')

# %%
len(sdf_rdtr)
# Out:
# 113976

# %%
domains = arcpy.da.ListDomains(os.path.join(workspace, 'RTRW Jakarta', '2.Pola Ruang RDTR', 'Standar Basis Data Peta RDTR Kabupaten-Kota.gdb'))
list_domain_rdtr = {}
for domain in domains:
    get_domain_name = domain.name
    if domain.domainType == 'CodedValue':
        coded_values = domain.codedValues
        list_domain_rdtr['{}'.format(get_domain_name)] = coded_values

# %%
list_domain_rdtr.keys()
# Out:
# dict_keys(['KODZON', '18KOD_PTL', '13KOD_KR', 'ORDE02SAMPAHPT', 'KODSBL', '12KOD_KHP', 'JNSRPR', '07KOD_ADT', 'LP2B', '22DES_SPU', '21DES_R', '04KOD_PS', 'KKOP', '16KOD_KEG', 'KRB', '02DES_HL', 'TOD', '05DES_RTH', 'TEB', 'PUSLIT', '23KOD_RTNH', 'CAGBUD', 'RESAIR', '10DES_EM', 'KSMPDN', '14KOD_P', 'HANKAM', 'KKARST', 'PTBGMB', '19KOD_KPI', 'MGRSAT', '03KOD_LG', 'RDBUMI', '01DES_BA', '15DES_IK', '08DES_LGE', '01KOD_BA', '02KOD_HL', '03DES_LG', '04DES_PS', '05KOD_RTH', '06DES_KS', '13DES_KR', '06KOD_KS', '16DES_KEG', '07DES_ADT', '08KOD_LGE', '09DES_CB', '17DES_T', '15KOD_IK', '09KOD_CB', '10KOD_EM', '11DES_BJ', '11KOD_BJ', '12DES_KHP', '14DES_P', 'ORDE01LAINNYAPT', '17KOD_T', 'ORDE02DRAINPT', '18DES_PTL', '19DES_KPI', '20DES_W', '20KOD_W', '21KOD_R', '22KOD_SPU', '23DES_RTNH', '24DES_C', 'ORDE02LAINNYALN', '24KOD_C', '25DES_K', '25KOD_K', '26DES_KT', '26KOD_KT', '27DES_PL', '27KOD_PL', '28DES_PP', '28KOD_PP', '29DES_TR', '29KOD_TR', '30DES_HK', 'ORDE01SAMPAHPT', '30KOD_HK', 'ORDE01AIRLN', 'ORDE01PUSATPT', 'STSJRN', 'ORDE02AIRLN', 'JNSRSR', 'ORDE01AIRPT', 'ORDE02AIRPT', 'ORDE01LIMBAHPT', 'ORDE02LIMBAHPT', 'ORDE01LIMBAHLN', 'ORDE02LIMBAHLN', 'ORDE01DRAINLN', 'ORDE02DRAINLN', 'ORDE01DRAINPT', 'ORDE01ENERGIPT', 'ORDE02ENERGIPT', 'ORDE01ENERGILN', 'ORDE02ENERGILN', 'ORDE01LAINNYALN', 'ORDE02LAINNYAPT', 'ORDE02PUSATPT', 'ORDE01SDAPT', 'ORDE02SDAPT', 'ORDE01SDALN', 'ORDE02SDALN', 'ORDE01TELEPT', 'ORDE02TELEPT', 'ORDE01TELELN', 'ORDE02TELELN', 'ORDE01TRANSPT', 'ORDE02TRANSPT', 'ORDE01TRANSLN', 'ORDE02TRANSLN'])

# %%
list_conv_str = ['KODZON', 'JNSRPR', 'KODSBL', 'KKOP', 'LP2B', 'KRB', 'TOD', 'TEB', 'PUSLIT', 'CAGBUD',
       'RESAIR', 'KSMPDN', 'HANKAM', 'KKARST', 'PTBGMB', 'MGRSAT', 'RDBUMI']

# %%
for subindex in list_conv_str:
    for index, row in sdf_rdtr.iterrows():
        get_column_value = row['{}'.format(subindex)]
        get_domain = list_domain_rdtr['{}'.format(subindex)]
        if get_column_value is not None:
            if get_column_value in get_domain:
                get_subvalue = get_domain[get_column_value]
                sdf_rdtr.loc[index, '{}_conv'.format(subindex)] = get_subvalue

# %%
sdf_rdtr.head(10)
# Out:
#    OBJECTID                   NAMOBJ    NAMZON      KODZON      NAMSZN  \
# 0    895222  Pertahanan dan Keamanan  32130000  32130000.0  32130000.0
# 1    895223              Badan Jalan  32010000  32010000.0  32010000.0
# 2    895224              Badan Jalan  32010000  32010000.0  32010000.0
# 3    895225              Badan Jalan  32010000  32010000.0  32010000.0
# 4    895226              Badan Jalan  32010000  32010000.0  32010000.0
# 5    895227              Badan Jalan  32010000  32010000.0  32010000.0
# 6    895228              Badan Jalan  32010000  32010000.0  32010000.0
# 7    895229              Badan Jalan  32010000  32010000.0  32010000.0
# 8    895230              Badan Jalan  32010000  32010000.0  32010000.0
# 9    895231              Badan Jalan  32010000  32010000.0  32010000.0
#
#      KODSZN      JNSRPR KODEWP KODSWP KODBLK  ...   TEB_conv PUSLIT_conv  \
# 0  32130000  32000000.0      I      A      1  ...  Tidak Ada   Tidak Ada
# 1  32010000  32000000.0      I      A      1  ...  Tidak Ada   Tidak Ada
# 2  32010000  32000000.0      I      A      1  ...  Tidak Ada   Tidak Ada
# 3  32010000  32000000.0      I      A      1  ...  Tidak Ada   Tidak Ada
# 4  32010000  32000000.0      I      A      1  ...  Tidak Ada   Tidak Ada
# 5  32010000  32000000.0      I      A      1  ...  Tidak Ada   Tidak Ada
# 6  32010000  32000000.0      I      A      1  ...  Tidak Ada   Tidak Ada
# 7  32010000  32000000.0      I      A      1  ...  Tidak Ada   Tidak Ada
# 8  32010000  32000000.0      I      A      1  ...  Tidak Ada   Tidak Ada
# 9  32010000  32000000.0      I      A      1  ...  Tidak Ada   Tidak Ada
#
#   CAGBUD_conv RESAIR_conv KSMPDN_conv HANKAM_conv KKARST_conv PTBGMB_conv  \
# 0   Tidak Ada   Tidak Ada   Tidak Ada   Tidak Ada   Tidak Ada   Tidak Ada
# 1   Tidak Ada   Tidak Ada   Tidak Ada   Tidak Ada   Tidak Ada   Tidak Ada
# 2   Tidak Ada   Tidak Ada   Tidak Ada   Tidak Ada   Tidak Ada   Tidak Ada
# 3   Tidak Ada   Tidak Ada   Tidak Ada   Tidak Ada   Tidak Ada   Tidak Ada
# 4   Tidak Ada   Tidak Ada   Tidak Ada   Tidak Ada   Tidak Ada   Tidak Ada
# 5   Tidak Ada   Tidak Ada   Tidak Ada   Tidak Ada   Tidak Ada   Tidak Ada
# 6   Tidak Ada   Tidak Ada   Tidak Ada   Tidak Ada   Tidak Ada   Tidak Ada
# 7   Tidak Ada   Tidak Ada   Tidak Ada   Tidak Ada   Tidak Ada   Tidak Ada
# 8   Tidak Ada   Tidak Ada   Tidak Ada   Tidak Ada   Tidak Ada   Tidak Ada
# 9   Tidak Ada   Tidak Ada   Tidak Ada   Tidak Ada   Tidak Ada   Tidak Ada
#
#   MGRSAT_conv RDBUMI_conv
# 0   Tidak Ada   Tidak Ada
# 1   Tidak Ada   Tidak Ada
# 2   Tidak Ada   Tidak Ada
# 3   Tidak Ada   Tidak Ada
# 4   Tidak Ada   Tidak Ada
# 5   Tidak Ada   Tidak Ada
# 6   Tidak Ada   Tidak Ada
# 7   Tidak Ada   Tidak Ada
# 8   Tidak Ada   Tidak Ada
# 9   Tidak Ada   Tidak Ada
#
# [10 rows x 50 columns]

# %%
sdf_rdtr.spatial.to_featureclass(location=os.path.join(workspace, 'JAKARTASATU.gdb', 'rdtr_modified'),overwrite=True,has_z=True, has_m=None, sanitize_columns=False)
# Out:
# 'E:\\PROJECT\\JAKARTASATU\\JAKARTASATU.gdb\\rdtr_modified'
