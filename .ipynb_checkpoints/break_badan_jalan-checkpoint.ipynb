# %%
import arcpy
import arcgis
import os
import pandas as pd
from datetime import datetime 

workspace = r'E:\PROJECT\JAKARTASATU'
workspace
# Out:
# 'E:\\PROJECT\\JAKARTASATU'

# %%
fc = os.path.join(workspace, 'badan_jalan_pieces.gdb', 'badan_jalan_all')
sdf = pd.DataFrame.spatial.from_featureclass(fc)
sdf.head(10)
# Out:
#    OBJECTID       NAMOBJ    NAMZON      KODZON      NAMSZN    KODSZN  \
# 0         1  Badan Jalan  32010000  32010000.0  32010000.0  32010000
# 1         2  Badan Jalan  32010000  32010000.0  32010000.0  32010000
# 2         3  Badan Jalan  32010000  32010000.0  32010000.0  32010000
# 3         4  Badan Jalan  32010000  32010000.0  32010000.0  32010000
# 4         5  Badan Jalan  32010000  32010000.0  32010000.0  32010000
# 5         6  Badan Jalan  32010000  32010000.0  32010000.0  32010000
# 6         7  Badan Jalan  32010000  32010000.0  32010000.0  32010000
# 7         8  Badan Jalan  32010000  32010000.0  32010000.0  32010000
# 8         9  Badan Jalan  32010000  32010000.0  32010000.0  32010000
# 9        10  Badan Jalan  32010000  32010000.0  32010000.0  32010000
#
#        JNSRPR KODEWP KODSWP KODBLK  ... PUSLIT_conv CAGBUD_conv RESAIR_conv  \
# 0  32000000.0      I      A      1  ...   Tidak Ada   Tidak Ada   Tidak Ada
# ...

# %%
sdf['temp_oid'] = sdf['OBJECTID']

# %%
len(sdf)
# Out:
# 42209

# %%
start = 0
end = 1000
for i in range(0, 43):
    print(start, end)
    if i == 0:
        select_sdf = sdf.iloc[start:end,:]
        output_location_sdf = os.path.join(workspace, 'badan_jalan_pieces.gdb', 'badan_jalan_{}'.format(i))
        start = end+1
        end = end+1001
        select_sdf.spatial.to_featureclass(location=output_location_sdf, overwrite=True)
    else:
        select_sdf = sdf.iloc[start:end,:]
        output_location_sdf = os.path.join(workspace, 'badan_jalan_pieces.gdb', 'badan_jalan_{}'.format(i))
        start = end+1
        end = end+(1000)
        select_sdf.spatial.to_featureclass(location=output_location_sdf, overwrite=True)
# Out:
# 0 1000
# E:\ARCPRO_ENV\jakartasatu\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# 1001 2001
# 2002 3001
# 3002 4001
# 4002 5001
# 5002 6001
# 6002 7001
# 7002 8001
# 8002 9001
# 9002 10001
# 10002 11001
# 11002 12001
# 12002 13001
# 13002 14001
# 14002 15001
# 15002 16001
# 16002 17001
# 17002 18001
# 18002 19001
# 19002 20001
# 20002 21001
# 21002 22001
# 22002 23001
# 23002 24001
# 24002 25001
# 25002 26001
# 26002 27001
# 27002 28001
# 28002 29001
# 29002 30001
# 30002 31001
# 31002 32001
# 32002 33001
# 33002 34001
# 34002 35001
# 35002 36001
# 36002 37001
# 37002 38001
# 38002 39001
# 39002 40001
# 40002 41001
# 41002 42001
# 42002 43001

# %%
main_index = 1301
sub_index = ['a','b']
kuisioner = [2,3,4,5]

for i in sub_index:
    for j in kuisioner:
        print('R{}{}{}'.format(main_index,i.upper(),j))
# Out:
# R1301A2
# R1301A3
# R1301A4
# R1301A5
# R1301B2
# R1301B3
# R1301B4
# R1301B5
